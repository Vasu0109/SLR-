# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Take-Home <br>(Day 1)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Import the required libraries

# %%
# type your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Read the data
#
# Load the csv file and set the first column as index

# %%
# type your code here
df = pd.read_csv("car_price.csv")
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# Our objective is to predict the selling price of the cars data.

# %% [markdown]
# **The data definition is as follows:** <br><br>
# **Car_Name:** name of the car <br>
#
# **YearThis:** year in which the car was bought <br>
#
# **Present_Price:** current ex-showroom price of the car (in lakhs)<br>
#
# **Kms_Driven:** distance completed by the car in km <br>
#
# **Fuel_Type:** fuel type of the car <br>
#
# **Seller_Type:** defines whether the seller is a dealer or an individual<br>
#
# **Transmission:** defines whether the car is manual or automatic <br>
#
# **Owner:** defines the number of owners the car has previously had <br>
#
# **Selling_Price:** price the owner wants to sell the car at (in lakhs) (response variable)

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Build a full model and interpret the beta coefficients </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#         Hint: A full model is a model which includes all the features

# %%
# type your code here
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Car_Name_encoded"] = le.fit_transform(df["Car_Name"])
df["Fuel_Type"] = df["Fuel_Type"].replace({"Petrol":0,"Diesel":1,"CNG":2})
df["Seller_Type"] = df["Seller_Type"].replace({"Dealer":0,"Individual":1})
df["Transmission"] = df["Transmission"].replace({"Manual":0,"Automatic":1})
x = df.drop(columns = ["Selling_Price","Car_Name"])
y = df["Selling_Price"]
from statsmodels import api
xc = api.add_constant(x)
ols_model = api.OLS(y,xc)
linear_model = ols_model.fit()
linear_model.summary()
# we have an R**2 value of 0.87
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Selling_Price   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     264.1
# Date:                Thu, 16 Dec 2021   Prob (F-statistic):          7.63e-129
# Time:                        10:15:22   Log-Likelihood:                -598.68
# No. Observations:                 301   AIC:                             1215.
# Df Residuals:                     292   BIC:                             1249.
# Df Model:                           8
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             -809.9146     87.940     -9.210      0.000    -982.992    -636.837
# Year                 0.4030      0.044      9.239      0.000       0.317       0.489
# Present_Price        0.4463      0.016     27.828      0.000       0.415       0.478
# Kms_Driven       -6.471e-06   3.29e-06     -1.965      0.050    -1.3e-05    1.05e-08
# Fuel_Type            1.5050      0.283      5.322      0.000       0.948       2.062
# Seller_Type         -1.1980      0.406     -2.952      0.003      -1.997      -0.399
# Transmission         1.4298      0.333      4.289      0.000       0.774       2.086
# Owner               -0.6763      0.430     -1.573      0.117      -1.523       0.170
# Car_Name_encoded    -0.0022      0.007     -0.303      0.762      -0.017       0.012
# ==============================================================================
# Omnibus:                       87.451   Durbin-Watson:                   1.762
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              667.597
# Skew:                           0.950   Prob(JB):                    1.08e-145
# Kurtosis:                      10.044   Cond. No.                     4.56e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.56e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Is there multicollinearity present? If yes, which variables are involved in multicollinearity?    </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. What is the impact of present price of the car and seller type on the selling price?
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.scatterplot(df["Present_Price"],df["Selling_Price"],hue = df["Seller_Type"])
# as the present price increases the selling price also increses irrespective of the selling type
# Out:
# C:\Users\WELCOME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Present_Price', ylabel='Selling_Price'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Consider all the numeric features in the data. Do all of them significantly contribute to explaining the variation in the selling price?
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df1 = pd.read_csv("car_price.csv")
num_df = df1.select_dtypes(include = np.number)
cat_df = df1.select_dtypes(exclude = np.number)
x = num_df.drop(columns = "Selling_Price")
y = num_df["Selling_Price"]
from statsmodels import api
xc = api.add_constant(x)
ols_model = api.OLS(y,xc)
linear_model = ols_model.fit()
linear_model.summary()
# KMS_dRIVEN IS LESS SIGNIFICANT FEATURE WHILE PREDICTING THE SELLING PRICE
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Selling_Price   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     426.6
# Date:                Thu, 16 Dec 2021   Prob (F-statistic):          1.66e-121
# Time:                        10:15:23   Log-Likelihood:                -628.25
# No. Observations:                 301   AIC:                             1267.
# Df Residuals:                     296   BIC:                             1285.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          -937.7642     94.392     -9.935      0.000   -1123.528    -752.000
# Year              0.4661      0.047      9.949      0.000       0.374       0.558
# Present_Price     0.5256      0.013     39.067      0.000       0.499       0.552
# Kms_Driven    -1.267e-06   3.51e-06     -0.361      0.718   -8.17e-06    5.64e-06
# Owner            -0.9513      0.466     -2.042      0.042      -1.868      -0.034
# ==============================================================================
# Omnibus:                       69.450   Durbin-Watson:                   1.560
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1362.873
# Skew:                           0.241   Prob(JB):                    1.14e-296
# Kurtosis:                      13.413   Cond. No.                     4.46e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.46e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. In the model obtained in question 4, consider the interaction effect of the present price of the car and the year in which it was purchased. Compare the resultant model with the model obtained in previous question and give your interpretation
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
x = num_df[["Present_Price","Year"]]
y = num_df["Selling_Price"]
from statsmodels import api
xc = api.add_constant(x)
ols_model = api.OLS(y,xc)
linear_model = ols_model.fit()
linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Selling_Price   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     844.7
# Date:                Thu, 16 Dec 2021   Prob (F-statistic):          1.64e-123
# Time:                        10:15:23   Log-Likelihood:                -630.42
# No. Observations:                 301   AIC:                             1267.
# Df Residuals:                     298   BIC:                             1278.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          -985.4594     79.494    -12.397      0.000   -1141.900    -829.019
# Present_Price     0.5246      0.013     39.731      0.000       0.499       0.551
# Year              0.4897      0.039     12.406      0.000       0.412       0.567
# ==============================================================================
# Omnibus:                       67.412   Durbin-Watson:                   1.526
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1300.900
# Skew:                           0.186   Prob(JB):                    3.26e-283
# Kurtosis:                      13.178   Cond. No.                     1.41e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. What is the impact of fuel type of cars on the selling price?
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.barplot(df1["Fuel_Type"],df1["Selling_Price"])
# Out:
# C:\Users\WELCOME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fuel_Type', ylabel='Selling_Price'>

# %%
#yes the selling price of diesel is quite high comparing to petrol and cng

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Does the model significantly explain variation in the target variable? Justify your answer with analysis of variation
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#             Regress the selling price over the transmission.
#
#             Selling_Price ~ Transmission

# %%
# type your code here
x = df["Transmission"]
y = df["Selling_Price"]
from statsmodels import api
xc = api.add_constant(x)
ols_model = api.OLS(y,xc)
linear_model = ols_model.fit()
linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Selling_Price   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     46.58
# Date:                Thu, 16 Dec 2021   Prob (F-statistic):           4.90e-11
# Time:                        10:15:24   Log-Likelihood:                -894.20
# No. Observations:                 301   AIC:                             1792.
# Df Residuals:                     299   BIC:                             1800.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            3.9320      0.293     13.413      0.000       3.355       4.509
# Transmission     5.4880      0.804      6.825      0.000       3.906       7.070
# ==============================================================================
# Omnibus:                      143.925   Durbin-Watson:                   1.182
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              946.055
# Skew:                           1.855   Prob(JB):                    3.69e-206
# Kurtosis:                      10.853   Cond. No.                         3.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Regress the selling price over the present price. Compare the 99% and 95% confidence interval of present price of a car
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
x = df["Present_Price"]
y = df["Selling_Price"]
from statsmodels import api
xc = api.add_constant(x)
ols_model = api.OLS(y,xc)
linear_model = ols_model.fit()
linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Selling_Price   R-squared:                       0.773
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     1016.
# Date:                Thu, 16 Dec 2021   Prob (F-statistic):           3.60e-98
# Time:                        10:15:24   Log-Likelihood:                -693.08
# No. Observations:                 301   AIC:                             1390.
# Df Residuals:                     299   BIC:                             1398.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.7185      0.187      3.847      0.000       0.351       1.086
# Present_Price     0.5168      0.016     31.874      0.000       0.485       0.549
# ==============================================================================
# Omnibus:                       59.775   Durbin-Watson:                   1.533
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              926.121
# Skew:                           0.084   Prob(JB):                    7.86e-202
# Kurtosis:                      11.592   Cond. No.                         15.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
linear_model.summary(alpha = 0.01)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Selling_Price   R-squared:                       0.773
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     1016.
# Date:                Thu, 16 Dec 2021   Prob (F-statistic):           3.60e-98
# Time:                        10:34:59   Log-Likelihood:                -693.08
# No. Observations:                 301   AIC:                             1390.
# Df Residuals:                     299   BIC:                             1398.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.005      0.995]
# ---------------------------------------------------------------------------------
# const             0.7185      0.187      3.847      0.000       0.234       1.203
# Present_Price     0.5168      0.016     31.874      0.000       0.475       0.559
# ==============================================================================
# Omnibus:                       59.775   Durbin-Watson:                   1.533
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              926.121
# Skew:                           0.084   Prob(JB):                    7.86e-202
# Kurtosis:                      11.592   Cond. No.                         15.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#95% confidence interval is  between 0.485 and 0.549
#99% confidence interval is between 0.475 and 0.559

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                         <b>9. Verify the statement: The sum of the residuals in any regression model that contains an intercept β<sub>0</sub> is always zero
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#         To verify the result, we will fit a regression model of 'Present_Price' on 'Selling_Price'

# %%
# type your code here
x = df["Present_Price"]
y = df["Selling_Price"]
from statsmodels import api
xc = api.add_constant(x)
ols_model = api.OLS(y,x)
linear_model = ols_model.fit()
linear_model.summary()
resid = linear_model.resid
y_pred = linear_model.predict()
SSE = ((y_pred  - y)**2)
SSE = np.sum(SSE)
SSR = np.sum((y_pred - np.mean(y))**2)
SSR,SSE
# Out:
# (7032.7088139000425, 1849.6166320187262)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Consider two models as specified below. Compare the performance of the models
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#                 First model:
#
#         Selling_Price ~ Year + Present_Price + Kms_Driven + Owner + Fuel_Type + Seller_Type + Transmission
#
#
#                 Second model:
#
#         Selling_Price ~ Year + Present_Price + Kms_Driven + Owner

# %%
# type your code here
x = df[["Present_Price","Year","Kms_Driven","Owner","Fuel_Type","Seller_Type","Transmission"]]
y = df["Selling_Price"]
from statsmodels import api
xc = api.add_constant(x)
ols_model = api.OLS(y,x)
linear_model = ols_model.fit()
linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:          Selling_Price   R-squared (uncentered):                   0.915
# Model:                            OLS   Adj. R-squared (uncentered):              0.913
# Method:                 Least Squares   F-statistic:                              450.8
# Date:                Thu, 16 Dec 2021   Prob (F-statistic):                   4.10e-153
# Time:                        10:57:35   Log-Likelihood:                         -637.48
# No. Observations:                 301   AIC:                                      1289.
# Df Residuals:                     294   BIC:                                      1315.
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Present_Price     0.4378      0.018     24.166      0.000       0.402       0.473
# Year              0.0010      0.000      8.196      0.000       0.001       0.001
# Kms_Driven    -2.276e-05   3.13e-06     -7.275      0.000   -2.89e-05   -1.66e-05
# Owner            -1.2604      0.482     -2.614      0.009      -2.209      -0.312
# Fuel_Type         1.8645      0.314      5.934      0.000       1.246       2.483
# Seller_Type      -1.2437      0.295     -4.213      0.000      -1.825      -0.663
# Transmission      1.7759      0.376      4.728      0.000       1.037       2.515
# ==============================================================================
# Omnibus:                       75.571   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              571.927
# Skew:                           0.781   Prob(JB):                    6.42e-125
# Kurtosis:                       9.570   Cond. No.                     2.22e+05
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.22e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x = df[["Present_Price","Year","Kms_Driven","Owner"]]
y = df["Selling_Price"]
from statsmodels import api
xc = api.add_constant(x)
ols_model = api.OLS(y,x)
linear_model = ols_model.fit()
linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:          Selling_Price   R-squared (uncentered):                   0.893
# Model:                            OLS   Adj. R-squared (uncentered):              0.892
# Method:                 Least Squares   F-statistic:                              620.4
# Date:                Thu, 16 Dec 2021   Prob (F-statistic):                   8.43e-143
# Time:                        10:57:58   Log-Likelihood:                         -671.56
# No. Observations:                 301   AIC:                                      1351.
# Df Residuals:                     297   BIC:                                      1366.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Present_Price     0.5349      0.015     34.571      0.000       0.504       0.565
# Year              0.0007      0.000      6.769      0.000       0.000       0.001
# Kms_Driven    -1.945e-05   3.45e-06     -5.635      0.000   -2.62e-05   -1.27e-05
# Owner            -1.6889      0.530     -3.185      0.002      -2.732      -0.645
# ==============================================================================
# Omnibus:                       65.420   Durbin-Watson:                   1.676
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1191.034
# Skew:                           0.165   Prob(JB):                    2.35e-259
# Kurtosis:                      12.739   Cond. No.                     2.17e+05
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.17e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#The first model has a better performance than the second model
